# %% [markdown]
# **Author: Oscar Ekberg**
#
# **Special Thanks to Tomas Nordström, Professor of Intelligent Embedded Systems at Umeå University & Responsible for Course Deep Learning - Methods and Applications (5TF078)**

# %% [markdown]
# # Fetching data from database

# %%
# Fetching data from Google Sheets
import gspread
import pandas as pd
from google.auth import default
from google.colab import auth
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)
spreadsheet = gc.open_by_key('1EH95aGJZQTrfI6G-5Hx73yCgkbQTKzk1QX_YJ9E7Dlk')
worksheet = spreadsheet.get_worksheet(0)
df = pd.DataFrame(worksheet.get_all_records())
# Prints first 6 tuples
print(df[:6])
# Out:
#    id                 date  temperature  humidity  eco2  tvoc
# 0   1  12/12/2025 15:40:54           22        47   400     0
# 1   2  12/12/2025 15:41:28           22        47   400     0
# 2   3  12/12/2025 15:42:03           22        47   402     0
# 3   4  12/12/2025 15:42:37           22        47   401     0
# 4   5  12/12/2025 15:43:12           22        47   400     0
# 5   6  12/12/2025 15:43:46           22        47   400     0

# %% [markdown]
# # Necessary Imports

# %%
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import keras
import numpy as np

# %% [markdown]
# # Determining current GPU

# %%
# Credit: Tomas Nordström, Umeå University
# Test for GPU and determine what GPU we have
import platform
import subprocess
gpu_devices = tf.config.list_physical_devices('GPU')

gpu_name = tf.test.gpu_device_name()
if gpu_name != '':
    print('TF-GPU-devname:',tf.test.gpu_device_name())
    sys_details = tf.sysconfig.get_build_info()
    physical_devices = tf.config.list_physical_devices('GPU')
    print("Num GPUs:", len(physical_devices))
    if platform.system() == "Darwin":
        print('GPU on Mac!')
    else:
        cuda_version = sys_details["cuda_version"]
        print('TF-cuda version:',cuda_version)
        if len(physical_devices)>0:
            process = subprocess.Popen(['nvidia-smi','-L'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            print(process.communicate())
        # If possible to run code with 16 bits float instead of 32 bits float, this code activates such functionality:
        if gpu_devices:
            details = tf.config.experimental.get_device_details(gpu_devices[0])
            compute_capability=details.get('compute_capability')
            print("Compute capability:",compute_capability)
            if compute_capability[0]>6:
                print("Turning on mixed_float16")
                policy = keras.mixed_precision.Policy('mixed_float16')
                keras.mixed_precision.set_global_policy(policy)
else:
    print('TF-device CPU')
# Out:
# TF-device CPU

# %% [markdown]
# # Exploring the data

# %%
print("Amount of rows in dataset:", df.shape[0])
print("Amount of attributes in dataset:", df.shape[1])

df.head()
# Out:
# Amount of rows in dataset: 14975
# Amount of attributes in dataset: 6
#    id                 date  temperature  humidity  eco2  tvoc
# 0   1  12/12/2025 15:40:54           22        47   400     0
# 1   2  12/12/2025 15:41:28           22        47   400     0
# 2   3  12/12/2025 15:42:03           22        47   402     0
# 3   4  12/12/2025 15:42:37           22        47   401     0
# 4   5  12/12/2025 15:43:12           22        47   400     0

# %% [markdown]
# # Exploring a few attributes evolution over time

# %%
# Credit: Tomas Nordström, Umeå University
print(df.columns)
df['date'] = pd.to_datetime(df['date'], dayfirst=True, format='mixed')
df = df.set_index('date')

plot_cols = ['temperature', 'humidity']
plot_features = df[plot_cols]
_ = plot_features.plot(subplots=True)
# Out:
# Index(['id', 'date', 'temperature', 'humidity', 'eco2', 'tvoc'], dtype='object')

# %% [markdown]
# # Inspect and cleanup of dataset

# %%
# Credit: Tomas Nordström, Umeå University
# Remove irrelevant id attribute
df = df.drop(columns=['id'])

df.describe().transpose()
# Out:
#                count        mean         std    min    25%    50%    75%  \
# temperature  14975.0   21.151452    0.518942   18.0   21.0   21.0   21.0
# humidity     14975.0   41.736427    4.817053   33.0   38.0   40.0   45.0
# eco2         14975.0  412.594324   85.358991  400.0  400.0  400.0  400.0
# tvoc         14975.0   29.503506  169.538250    0.0    0.0    0.0    0.0
#
#                  max
# temperature     23.0
# humidity        66.0
# eco2          3699.0
# tvoc         10706.0

# %% [markdown]
# **The data looks clean, no outliers 🙂**

# %% [markdown]
# # When measuring the data I noticed that the RPI Pico stopped measuring at two points of time due to exceeded memory.
#
# # This is why we need to find the gaps in the dataset where no measures were made every 30-35 seconds. (I chose to filter through when no measures were made in 90 seconds instead of 30-35 because sometimes the data post took about 1 minute due to slow routing)

# %%
df = df.sort_index()

gaps = pd.DataFrame({
  "before": df.index.to_series().shift(1),
  "after": df.index,
  "gap": df.index.to_series().diff(),
  "row_ix": range(len(df))
})

# Threshold for minimum gap to be measured
threshold = pd.Timedelta(seconds=90)

# Defining missed measures where the time inbetween two measures are greater than 90 seconds
gaps = gaps[gaps["gap"] > threshold]

display(gaps)
# Out:
#                                  before               after             gap  \
# date
# 2025-12-17 14:10:22 2025-12-17 14:05:33 2025-12-17 14:10:22 0 days 00:04:49
# 2025-12-17 19:14:13 2025-12-17 14:10:22 2025-12-17 19:14:13 0 days 05:03:51
# 2025-12-18 10:03:48 2025-12-18 00:30:59 2025-12-18 10:03:48 0 days 09:32:49
#
#                      row_ix
# date
# 2025-12-17 14:10:22   12229
# 2025-12-17 19:14:13   12230
# 2025-12-18 10:03:48   12774

# %% [markdown]
# **We found three larger gaps in the dataset**
#
# **Gap 1: 5 minutes**
#
# **Gap 2: 5 hours**
#
# **Gap 3: 9.5 hours**

# %% [markdown]
# # Adding the missing values
#
# **The most recent values measured will be applied for all missed measurments for the respective gap**

# %% [markdown]
# **The three indexes where the gaps are in the dataset**

# %%
indexOfGaps = gaps['row_ix'].tolist()

print(indexOfGaps)
# Out:
# [12229, 12230, 12774]

# %% [markdown]
# **The RPI Pico is programmed to measure every 30 seconds, but sending data to google sheets adds a few seconds, irregurlary.**

# %% [markdown]
# **In order to add the correct amount missing data, I need to find the average time in between measurements.**

# %%
# Filtering out the larger gaps from the dataset.
time_diff = df.index.to_series().diff()

valid_measurements = time_diff[time_diff <= threshold]

print(valid_measurements)
print()

# Calculating the average value of each time difference
avg_valid_measurements = valid_measurements.dt.total_seconds().mean()

print(f'Average time between measurements {avg_valid_measurements:.2f}')
# Out:
# date
# 2025-12-12 15:41:28   0 days 00:00:34
# 2025-12-12 15:42:03   0 days 00:00:35
# 2025-12-12 15:42:37   0 days 00:00:34
# 2025-12-12 15:43:12   0 days 00:00:35
# 2025-12-12 15:43:46   0 days 00:00:34
#                             ...
# 2025-12-19 07:37:03   0 days 00:00:34
# 2025-12-19 07:37:40   0 days 00:00:37
# 2025-12-19 07:38:15   0 days 00:00:35
# 2025-12-19 07:38:50   0 days 00:00:35
# 2025-12-19 07:39:24   0 days 00:00:34
# Name: date, Length: 14971, dtype: timedelta64[ns]
#
# Average time between measurements 34.94

# %% [markdown]
# # Let us explore about how many measures were missed.

# %% [markdown]
# **Gap 1: (5 * 60) / 35**
#
# **Gap 2: (5 * 60 * 60) / 35**
#
# **Gap 3: (9.5 * 60 * 60) / 35**
#
# **Gap 1 resulted in 9 missed measures.**
#
# **Gap 2 resulted in 514 missed measures.**
#
# **Gap 3 resulted in 977 missed measures.**

# %% [markdown]
# **Notice that when I found the three gaps I disregarded smaller gaps, shorter than 90 seconds.**
#
# **Below all of these smaller gaps will be filled as well as the larger ones.**

# %%
df_35s = df.resample("35s").mean()
df_filled = df_35s.ffill()

print(df)
print(df_filled)
# Out:
#                      temperature  humidity  eco2  tvoc
# date
# 2025-12-12 15:40:54           22        47   400     0
# 2025-12-12 15:41:28           22        47   400     0
# 2025-12-12 15:42:03           22        47   402     0
# 2025-12-12 15:42:37           22        47   401     0
# 2025-12-12 15:43:12           22        47   400     0
# ...                          ...       ...   ...   ...
# 2025-12-19 07:37:03           20        47   400     0
# 2025-12-19 07:37:40           20        47   400     0
# 2025-12-19 07:38:15           20        47   400     0
# 2025-12-19 07:38:50           20        47   400     0
# 2025-12-19 07:39:24           20        47   400     0
#
# [14975 rows x 4 columns]
#                      temperature  humidity   eco2  tvoc
# date
# 2025-12-12 15:40:20         22.0      47.0  400.0   0.0
# 2025-12-12 15:40:55         22.0      47.0  400.0   0.0
# 2025-12-12 15:41:30         22.0      47.0  402.0   0.0
# 2025-12-12 15:42:05         22.0      47.0  401.0   0.0
# 2025-12-12 15:42:40         22.0      47.0  400.0   0.0
# ...                          ...       ...    ...   ...
# 2025-12-19 07:36:45         20.0      47.0  400.0   0.0
# 2025-12-19 07:37:20         20.0      47.0  400.0   0.0
# 2025-12-19 07:37:55         20.0      47.0  400.0   0.0
# 2025-12-19 07:38:30         20.0      47.0  400.0   0.0
# 2025-12-19 07:39:05         20.0      47.0  400.0   0.0
#
# [16456 rows x 4 columns]

# %% [markdown]
# **The original dataset consists of 14 976 rows.**
#
# **The filled dataset consists of 16 456 rows**
#
# **The dataset increased of 16456 - 14976 = 1480 rows**

# %% [markdown]
# # We want to predict 1 hour into the future, so we divide the dataset into 1 hour steps

# %%
df_1h = df.resample("1h").mean()
df_1h = df_1h.dropna() # Remove all NaN tuples
print("Amount of rows with 1 hour windows:", len(df_1h))
# Out:
# Amount of rows with 1 hour windows: 148

# %% [markdown]
# # Normalize the data

# %%
# Credit: Tomas Nordström, Umeå University
# Split the data into datasets
DataSplitRatios = (0.7, 0.2, 0.1)
n = len(df_1h)
split1ix = int(n*DataSplitRatios[0])
split2ix = int(n*(DataSplitRatios[0] + DataSplitRatios[1]))
print(split1ix, split2ix, n)
# Out:
# 103 133 148

# %% [markdown]
# It is important to scale features before training a neural network. Normalization is a common way of doing this scaling. Subtract the mean and divide by the standard deviation of each feature. Note that the mean and standard deviation should only be computed using the training data so that the models have no access to the values in the validation and test sets.
#
# The data is normalized so that the data is in the same distribution which makes the models to be able to learn easier (Tomas Nordström, 2025-05-08).

# %%
# Credit: Tomas Nordström, Umeå University
train_mean = df_1h[0:split1ix].mean()
train_std = df_1h[0:split1ix].std()
dfnorm = (df_1h - train_mean) / train_std

# %% [markdown]
# # Exploring distribution of normalized features

# %%
# Credit: Tomas Nordström, Umeå University
import seaborn as sns

df_std = dfnorm.melt(var_name='Column', value_name='Normalized')
plt.figure(figsize=(12, 6))
ax = sns.violinplot(x='Column', y='Normalized', data=df_std)
_ = ax.set_xticklabels(df_1h.keys(), rotation=45)
# Out:
# /tmp/ipython-input-2279449810.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(df_1h.keys(), rotation=45)

# %% [markdown]
# # Prepare our three datasets

# %%
# Credit: Tomas Nordström, Umeå University
def get_label_columns_indices(dataframe, label_columns=None):
    """
    Returns a dictionary mapping column names to their indices in the given DataFrame.
    Parameters:
        dataframe : pandas.DataFrame
            The DataFrame from which to extract column indices.
        label_columns : list of str, optional
            A list of column names to retrieve indices for. If None, all columns will be included.
    Returns:
        A dictionary where keys are column names and values are their corresponding indices.
    """
    if label_columns is None:
        # Return indices for all columns
        label_columns_indices = {name: i for i, name in enumerate(dataframe.columns)}
    else:
        # Return indices only for the specified label columns
        label_columns_indices = {name: dataframe.columns.get_loc(name) for name in label_columns}
    return label_columns_indices

# %%
# Test get_label_columns_indices
lcol= None
lci = get_label_columns_indices(dfnorm,lcol)
print(lci)
lcol= lcol= ['temperature']
lci = get_label_columns_indices(dfnorm,lcol)
print(lci)
# Out:
# {'temperature': 0, 'humidity': 1, 'eco2': 2, 'tvoc': 3}
# {'temperature': 0}

# %%
# Credit: Tomas Nordström, Umeå University
# Define a windowing function that converts a dataframe into a TF dataset
# Had to jump to some hoops for this as keras.utils.timeseries_dataset_from_array do not support label_width>1
# https://github.com/keras-team/tf-keras/issues/7
def datasetgen(dataframe, input_width=128, label_width=1, shift=1, batch_size=128,
  label_columns=None, start_index=None, end_index=None, shuffle=False):
  """
  Generate timeseries dataset from the given dataframe containing a data sequence.

  Parameters:
  - dataframe: The source time sequence dataframe.
  - input_width: Number of time steps in each input sequence.
  - label_width: Number of time steps in each label sequence.
  - shift: How many steps to shift the end of the input to get the label.
  - batch_size: Size of batches to generate.
  - label_columns: List of column names to extract as labels. If None, all columns are used.
  - start_index: Start index from the dataframe to consider data. Default is the start of the dataframe.
  - end_index: End index from the dataframe to consider data. Default is the end of the dataframe.
  - shuffle: Whether to shuffle the generated batches. Note: shuffling won't work in the current implementation.

  Returns:
  - A TensorFlow Dataset containing input and label sequences.
  """

  # If end index or start index is not given, assign them to the end or start of the dataframe respectively.
  if end_index is None:
      end_index = len(dataframe) + input_width - 1
  if start_index is None:
      start_index = 0

  # Generate a input timeseries dataset from the dataframe using keras.utils.timeseries_dataset_from_array
  input_ds = keras.utils.timeseries_dataset_from_array(
                  dataframe, targets=None, sequence_length=input_width,
                  sequence_stride=1, sampling_rate=1, batch_size=batch_size, shuffle=shuffle,
                  start_index=start_index, end_index=(end_index-(input_width+shift)))

  # Fetch the indices of the label columns from the dataframe.
  label_columns_indices = get_label_columns_indices(dataframe,label_columns) # get the selected columns
  targetsdf = dataframe[list(label_columns_indices)] # Note that we only use names and not the indices

  # Generate a timeseries dataset of label sequences from the dataframe.
  # Here we assume that label_width should be less than or equal to shift.
  target_ds = keras.utils.timeseries_dataset_from_array(
                  targetsdf, targets=None, sequence_length=label_width,
                  sequence_stride=1, sampling_rate=1, batch_size=batch_size, shuffle=shuffle,
                  start_index=(start_index+(input_width+shift-label_width)),
                  end_index=end_index-input_width)

  # Combine input and target datasets to form a single dataset.
  train_ds = tf.data.Dataset.zip(input_ds,target_ds)

  return train_ds

# %%
# Split targets

def split_targets(inputs, targets):
    targets = tf.squeeze(targets, axis=1)  # (batch, 4)
    return inputs, {
        "temperature": targets[:, 0],
        "humidity":  targets[:, 1],
        "eco2": targets[:, 2],
        "tvoc": targets[:, 3],
    }

# %%
# Now create the used datasets

input_width=12
shift=1           # How many steps to target
label_width=1     # Target sequence length
lcol=['temperature', 'humidity', 'eco2', 'tvoc'] # Target parameter(s)
train_ds = datasetgen(dfnorm, input_width=input_width, label_width=label_width, shift=shift,
              label_columns=lcol, start_index=0, end_index=split1ix)
val_ds = datasetgen(dfnorm, input_width=input_width, label_width=label_width, shift=shift,
              label_columns=lcol, start_index=split1ix, end_index=split2ix)
test_ds = datasetgen(dfnorm, input_width=input_width, label_width=label_width, shift=shift,
              label_columns=lcol, start_index=split2ix, end_index=None)

train_ds = train_ds.map(split_targets)
val_ds   = val_ds.map(split_targets)
test_ds  = test_ds.map(split_targets)

# %%
# Establish test targets (to show how to unroll dataset)
# Discussed with ChatGPT how to transform target establishing from one target to 4.

test_targets = {
    "temperature": [],
    "humidity": [],
    "eco2": [],
    "tvoc": []
}
for inputs, targets in test_ds:
  for x in test_targets:
    test_targets[x].append(targets[x])

for x in test_targets:
  test_targets[x] = tf.concat(test_targets[x], axis=0)

# %%
# Get a batch and look at the shapes for one of the datasets
eval_ds = test_ds

for inputs, targets in eval_ds.take(1):
  for key, value in targets.items():
    print(key, value.shape)
# Out:
# temperature (2,)
# humidity (2,)
# eco2 (2,)
# tvoc (2,)

# %% [markdown]
# # Finally the datasets are ready for training

# %% [markdown]
# **Exploring loss function**

# %% [markdown]
# Defining method for compiling and fitting data

# %%
# For reference when compiling a multile output LSTM: https://keras.io/guides/functional_api/

import time

def compile_and_fit(model, train_ds, val_ds, patience=5):
  MAX_EPOCHS = 30
  early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min',
                                                    restore_best_weights = True)

  model.compile(optimizer=tf.optimizers.Adam(),
                loss={
                    "temperature": "mse",
                    "humidity": "mse",
                    "eco2": "mse",
                    "tvoc": "mse"
                },
                loss_weights={
                  "temperature": 1.0,
                  "humidity": 1.0,
                  "eco2": 0.5,
                  "tvoc": 0.3
                },
                metrics={
                    "temperature": "mae",
                    "humidity": "mae",
                    "eco2": "mae",
                    "tvoc": "mae"
                }
              )

  start = time.time()
  history = model.fit(train_ds, epochs=MAX_EPOCHS,
                      validation_data=val_ds,
                      callbacks=[early_stopping])
  end = time.time()
  print(f'Time to run: {end - start:.1f}s')

  return history,model

# %% [markdown]
# # Creating a model

# %%
# Define a LSTM-model with multiple outputs
# For reference when creating a multile output LSTM: https://keras.io/guides/functional_api/

num_input_features = dfnorm.shape[1]

inputs = keras.Input(shape=(input_width, num_input_features))
lstm_layer = keras.layers.LSTM(64, return_sequences=False)(inputs)

temp = keras.layers.Dense(1, name="temperature")(lstm_layer)
hum = keras.layers.Dense(1, name="humidity")(lstm_layer)
eco2 = keras.layers.Dense(1, name="eco2")(lstm_layer)
tvoc = keras.layers.Dense(1, name="tvoc", activation="relu")(lstm_layer) # Realized i predicted negative tvoc values, which is physically impossible. References: https://www.reddit.com/r/learnmachinelearning/comments/eisotm/what_is_the_best_way_to_deal_with_negative/ & https://keras.io/api/layers/core_layers/dense/

lstm_model = keras.Model(
    inputs = inputs,
    outputs = [temp, hum, eco2, tvoc]
)

# %% [markdown]
# **Compile and train model**

# %%
history_lstm_model, lstm_model=compile_and_fit(lstm_model, train_ds, val_ds)
# Out:
# Epoch 1/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - eco2_loss: 0.5577 - eco2_mae: 0.3327 - humidity_loss: 0.5992 - humidity_mae: 0.6066 - loss: 1.9128 - temperature_loss: 0.7013 - temperature_mae: 0.7468 - tvoc_loss: 1.1113 - tvoc_mae: 0.6845 - val_eco2_loss: 0.2469 - val_eco2_mae: 0.4967 - val_humidity_loss: 2.7051 - val_humidity_mae: 1.2501 - val_loss: 3.3700 - val_temperature_loss: 0.3997 - val_temperature_mae: 0.6319 - val_tvoc_loss: 0.4722 - val_tvoc_mae: 0.6871
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - eco2_loss: 0.5504 - eco2_mae: 0.3302 - humidity_loss: 0.5810 - humidity_mae: 0.5911 - loss: 1.8457 - temperature_loss: 0.6596 - temperature_mae: 0.7211 - tvoc_loss: 1.0996 - tvoc_mae: 0.6774 - val_eco2_loss: 0.2298 - val_eco2_mae: 0.4791 - val_humidity_loss: 2.6600 - val_humidity_mae: 1.2311 - val_loss: 3.2709 - val_temperature_loss: 0.3618 - val_temperature_mae: 0.6011 - val_tvoc_loss: 0.4473 - val_tvoc_mae: 0.6688
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - eco2_loss: 0.5436 - eco2_mae: 0.3283 - humidity_loss: 0.5641 - humidity_mae: 0.5774 - loss: 1.7819 - temperature_loss: 0.6197 - temperature_mae: 0.6953 - tvoc_loss: 1.0874 - tvoc_mae: 0.6704 - val_eco2_loss: 0.2135 - val_eco2_mae: 0.4617 - val_humidity_loss: 2.6170 - val_humidity_mae: 1.2127 - val_loss: 3.1751 - val_temperature_loss: 0.3248 - val_temperature_mae: 0.5695 - val_tvoc_loss: 0.4221 - val_tvoc_mae: 0.6496
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - eco2_loss: 0.5371 - eco2_mae: 0.3264 - humidity_loss: 0.5485 - humidity_mae: 0.5640 - loss: 1.7214 - temperature_loss: 0.5818 - temperature_mae: 0.6692 - tvoc_loss: 1.0754 - tvoc_mae: 0.6638 - val_eco2_loss: 0.1978 - val_eco2_mae: 0.4444 - val_humidity_loss: 2.5758 - val_humidity_mae: 1.1948 - val_loss: 3.0820 - val_temperature_loss: 0.2884 - val_temperature_mae: 0.5366 - val_tvoc_loss: 0.3964 - val_tvoc_mae: 0.6296
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - eco2_loss: 0.5309 - eco2_mae: 0.3243 - humidity_loss: 0.5341 - humidity_mae: 0.5513 - loss: 1.6644 - temperature_loss: 0.5457 - temperature_mae: 0.6427 - tvoc_loss: 1.0638 - tvoc_mae: 0.6579 - val_eco2_loss: 0.1827 - val_eco2_mae: 0.4272 - val_humidity_loss: 2.5361 - val_humidity_mae: 1.1773 - val_loss: 2.9915 - val_temperature_loss: 0.2529 - val_temperature_mae: 0.5024 - val_tvoc_loss: 0.3704 - val_tvoc_mae: 0.6086
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - eco2_loss: 0.5250 - eco2_mae: 0.3224 - humidity_loss: 0.5209 - humidity_mae: 0.5392 - loss: 1.6108 - temperature_loss: 0.5116 - temperature_mae: 0.6157 - tvoc_loss: 1.0526 - tvoc_mae: 0.6528 - val_eco2_loss: 0.1683 - val_eco2_mae: 0.4100 - val_humidity_loss: 2.4979 - val_humidity_mae: 1.1603 - val_loss: 2.9040 - val_temperature_loss: 0.2187 - val_temperature_mae: 0.4671 - val_tvoc_loss: 0.3442 - val_tvoc_mae: 0.5866
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - eco2_loss: 0.5194 - eco2_mae: 0.3208 - humidity_loss: 0.5087 - humidity_mae: 0.5278 - loss: 1.5607 - temperature_loss: 0.4796 - temperature_mae: 0.5883 - tvoc_loss: 1.0422 - tvoc_mae: 0.6488 - val_eco2_loss: 0.1544 - val_eco2_mae: 0.3926 - val_humidity_loss: 2.4612 - val_humidity_mae: 1.1437 - val_loss: 2.8199 - val_temperature_loss: 0.1860 - val_temperature_mae: 0.4307 - val_tvoc_loss: 0.3183 - val_tvoc_mae: 0.5641
# Epoch 8/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - eco2_loss: 0.5141 - eco2_mae: 0.3194 - humidity_loss: 0.4975 - humidity_mae: 0.5171 - loss: 1.5144 - temperature_loss: 0.4498 - temperature_mae: 0.5604 - tvoc_loss: 1.0334 - tvoc_mae: 0.6468 - val_eco2_loss: 0.1410 - val_eco2_mae: 0.3752 - val_humidity_loss: 2.4260 - val_humidity_mae: 1.1275 - val_loss: 2.7397 - val_temperature_loss: 0.1552 - val_temperature_mae: 0.3934 - val_tvoc_loss: 0.2931 - val_tvoc_mae: 0.5413
# Epoch 9/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step - eco2_loss: 0.5091 - eco2_mae: 0.3179 - humidity_loss: 0.4874 - humidity_mae: 0.5071 - loss: 1.4716 - temperature_loss: 0.4224 - temperature_mae: 0.5321 - tvoc_loss: 1.0245 - tvoc_mae: 0.6450 - val_eco2_loss: 0.1280 - val_eco2_mae: 0.3575 - val_humidity_loss: 2.3919 - val_humidity_mae: 1.1117 - val_loss: 2.6630 - val_temperature_loss: 0.1266 - val_temperature_mae: 0.3552 - val_tvoc_loss: 0.2683 - val_tvoc_mae: 0.5179
# Epoch 10/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - eco2_loss: 0.5043 - eco2_mae: 0.3162 - humidity_loss: 0.4782 - humidity_mae: 0.4977 - loss: 1.4325 - temperature_loss: 0.3975 - temperature_mae: 0.5040 - tvoc_loss: 1.0158 - tvoc_mae: 0.6433 - val_eco2_loss: 0.1155 - val_eco2_mae: 0.3395 - val_humidity_loss: 2.3585 - val_humidity_mae: 1.0961 - val_loss: 2.5899 - val_temperature_loss: 0.1004 - val_temperature_mae: 0.3162 - val_tvoc_loss: 0.2440 - val_tvoc_mae: 0.4938
# Epoch 11/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - eco2_loss: 0.4997 - eco2_mae: 0.3148 - humidity_loss: 0.4700 - humidity_mae: 0.4895 - loss: 1.3974 - temperature_loss: 0.3753 - temperature_mae: 0.4763 - tvoc_loss: 1.0075 - tvoc_mae: 0.6422 - val_eco2_loss: 0.1034 - val_eco2_mae: 0.3212 - val_humidity_loss: 2.3255 - val_humidity_mae: 1.0804 - val_loss: 2.5203 - val_temperature_loss: 0.0771 - val_temperature_mae: 0.2769 - val_tvoc_loss: 0.2200 - val_tvoc_mae: 0.4690
# Epoch 12/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - eco2_loss: 0.4955 - eco2_mae: 0.3137 - humidity_loss: 0.4627 - humidity_mae: 0.4836 - loss: 1.3665 - temperature_loss: 0.3560 - temperature_mae: 0.4504 - tvoc_loss: 1.0003 - tvoc_mae: 0.6430 - val_eco2_loss: 0.0918 - val_eco2_mae: 0.3026 - val_humidity_loss: 2.2928 - val_humidity_mae: 1.0647 - val_loss: 2.4547 - val_temperature_loss: 0.0568 - val_temperature_mae: 0.2376 - val_tvoc_loss: 0.1972 - val_tvoc_mae: 0.4440
# Epoch 13/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - eco2_loss: 0.4916 - eco2_mae: 0.3126 - humidity_loss: 0.4564 - humidity_mae: 0.4804 - loss: 1.3398 - temperature_loss: 0.3394 - temperature_mae: 0.4262 - tvoc_loss: 0.9939 - tvoc_mae: 0.6446 - val_eco2_loss: 0.0806 - val_eco2_mae: 0.2836 - val_humidity_loss: 2.2605 - val_humidity_mae: 1.0489 - val_loss: 2.3936 - val_temperature_loss: 0.0399 - val_temperature_mae: 0.1990 - val_tvoc_loss: 0.1761 - val_tvoc_mae: 0.4196
# Epoch 14/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - eco2_loss: 0.4880 - eco2_mae: 0.3119 - humidity_loss: 0.4510 - humidity_mae: 0.4799 - loss: 1.3168 - temperature_loss: 0.3254 - temperature_mae: 0.4047 - tvoc_loss: 0.9881 - tvoc_mae: 0.6465 - val_eco2_loss: 0.0701 - val_eco2_mae: 0.2643 - val_humidity_loss: 2.2289 - val_humidity_mae: 1.0333 - val_loss: 2.3416 - val_temperature_loss: 0.0264 - val_temperature_mae: 0.1617 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 15/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - eco2_loss: 0.4848 - eco2_mae: 0.3114 - humidity_loss: 0.4464 - humidity_mae: 0.4811 - loss: 1.2972 - temperature_loss: 0.3135 - temperature_mae: 0.3869 - tvoc_loss: 0.9829 - tvoc_mae: 0.6487 - val_eco2_loss: 0.0602 - val_eco2_mae: 0.2449 - val_humidity_loss: 2.1985 - val_humidity_mae: 1.0180 - val_loss: 2.2961 - val_temperature_loss: 0.0162 - val_temperature_mae: 0.1266 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 16/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - eco2_loss: 0.4819 - eco2_mae: 0.3116 - humidity_loss: 0.4425 - humidity_mae: 0.4829 - loss: 1.2801 - temperature_loss: 0.3030 - temperature_mae: 0.3753 - tvoc_loss: 0.9786 - tvoc_mae: 0.6510 - val_eco2_loss: 0.0511 - val_eco2_mae: 0.2256 - val_humidity_loss: 2.1700 - val_humidity_mae: 1.0033 - val_loss: 2.2558 - val_temperature_loss: 0.0090 - val_temperature_mae: 0.0943 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 17/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - eco2_loss: 0.4794 - eco2_mae: 0.3122 - humidity_loss: 0.4389 - humidity_mae: 0.4844 - loss: 1.2646 - temperature_loss: 0.2934 - temperature_mae: 0.3668 - tvoc_loss: 0.9752 - tvoc_mae: 0.6535 - val_eco2_loss: 0.0430 - val_eco2_mae: 0.2067 - val_humidity_loss: 2.1438 - val_humidity_mae: 0.9896 - val_loss: 2.2208 - val_temperature_loss: 0.0043 - val_temperature_mae: 0.0652 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 18/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - eco2_loss: 0.4772 - eco2_mae: 0.3129 - humidity_loss: 0.4356 - humidity_mae: 0.4851 - loss: 1.2500 - temperature_loss: 0.2840 - temperature_mae: 0.3592 - tvoc_loss: 0.9725 - tvoc_mae: 0.6560 - val_eco2_loss: 0.0358 - val_eco2_mae: 0.1885 - val_humidity_loss: 2.1204 - val_humidity_mae: 0.9771 - val_loss: 2.1911 - val_temperature_loss: 0.0016 - val_temperature_mae: 0.0396 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 19/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - eco2_loss: 0.4752 - eco2_mae: 0.3132 - humidity_loss: 0.4322 - humidity_mae: 0.4849 - loss: 1.2355 - temperature_loss: 0.2746 - temperature_mae: 0.3522 - tvoc_loss: 0.9706 - tvoc_mae: 0.6583 - val_eco2_loss: 0.0295 - val_eco2_mae: 0.1711 - val_humidity_loss: 2.1001 - val_humidity_mae: 0.9661 - val_loss: 2.1664 - val_temperature_loss: 3.2589e-04 - val_temperature_mae: 0.0176 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 20/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - eco2_loss: 0.4734 - eco2_mae: 0.3132 - humidity_loss: 0.4285 - humidity_mae: 0.4839 - loss: 1.2209 - temperature_loss: 0.2650 - temperature_mae: 0.3444 - tvoc_loss: 0.9691 - tvoc_mae: 0.6603 - val_eco2_loss: 0.0242 - val_eco2_mae: 0.1547 - val_humidity_loss: 2.0834 - val_humidity_mae: 0.9567 - val_loss: 2.1467 - val_temperature_loss: 1.2189e-05 - val_temperature_mae: 0.0029 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 21/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - eco2_loss: 0.4716 - eco2_mae: 0.3126 - humidity_loss: 0.4246 - humidity_mae: 0.4820 - loss: 1.2059 - temperature_loss: 0.2555 - temperature_mae: 0.3357 - tvoc_loss: 0.9669 - tvoc_mae: 0.6620 - val_eco2_loss: 0.0197 - val_eco2_mae: 0.1395 - val_humidity_loss: 2.0702 - val_humidity_mae: 0.9492 - val_loss: 2.1316 - val_temperature_loss: 3.2003e-04 - val_temperature_mae: 0.0171 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 22/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - eco2_loss: 0.4699 - eco2_mae: 0.3114 - humidity_loss: 0.4204 - humidity_mae: 0.4795 - loss: 1.1912 - temperature_loss: 0.2462 - temperature_mae: 0.3268 - tvoc_loss: 0.9654 - tvoc_mae: 0.6637 - val_eco2_loss: 0.0160 - val_eco2_mae: 0.1255 - val_humidity_loss: 2.0604 - val_humidity_mae: 0.9433 - val_loss: 2.1206 - val_temperature_loss: 0.0010 - val_temperature_mae: 0.0307 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 23/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - eco2_loss: 0.4682 - eco2_mae: 0.3094 - humidity_loss: 0.4160 - humidity_mae: 0.4764 - loss: 1.1769 - temperature_loss: 0.2376 - temperature_mae: 0.3194 - tvoc_loss: 0.9644 - tvoc_mae: 0.6652 - val_eco2_loss: 0.0130 - val_eco2_mae: 0.1128 - val_humidity_loss: 2.0538 - val_humidity_mae: 0.9392 - val_loss: 2.1135 - val_temperature_loss: 0.0019 - val_temperature_mae: 0.0425 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 24/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - eco2_loss: 0.4664 - eco2_mae: 0.3073 - humidity_loss: 0.4115 - humidity_mae: 0.4728 - loss: 1.1635 - temperature_loss: 0.2297 - temperature_mae: 0.3154 - tvoc_loss: 0.9635 - tvoc_mae: 0.6665 - val_eco2_loss: 0.0105 - val_eco2_mae: 0.1013 - val_humidity_loss: 2.0501 - val_humidity_mae: 0.9366 - val_loss: 2.1096 - val_temperature_loss: 0.0030 - val_temperature_mae: 0.0531 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 25/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - eco2_loss: 0.4646 - eco2_mae: 0.3048 - humidity_loss: 0.4070 - humidity_mae: 0.4690 - loss: 1.1510 - temperature_loss: 0.2228 - temperature_mae: 0.3137 - tvoc_loss: 0.9629 - tvoc_mae: 0.6676 - val_eco2_loss: 0.0086 - val_eco2_mae: 0.0910 - val_humidity_loss: 2.0490 - val_humidity_mae: 0.9353 - val_loss: 2.1088 - val_temperature_loss: 0.0043 - val_temperature_mae: 0.0632 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 26/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - eco2_loss: 0.4628 - eco2_mae: 0.3019 - humidity_loss: 0.4027 - humidity_mae: 0.4657 - loss: 1.1396 - temperature_loss: 0.2168 - temperature_mae: 0.3127 - tvoc_loss: 0.9624 - tvoc_mae: 0.6685 - val_eco2_loss: 0.0070 - val_eco2_mae: 0.0819 - val_humidity_loss: 2.0499 - val_humidity_mae: 0.9352 - val_loss: 2.1104 - val_temperature_loss: 0.0058 - val_temperature_mae: 0.0733 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 27/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - eco2_loss: 0.4610 - eco2_mae: 0.2987 - humidity_loss: 0.3986 - humidity_mae: 0.4628 - loss: 1.1293 - temperature_loss: 0.2116 - temperature_mae: 0.3117 - tvoc_loss: 0.9620 - tvoc_mae: 0.6693 - val_eco2_loss: 0.0058 - val_eco2_mae: 0.0739 - val_humidity_loss: 2.0523 - val_humidity_mae: 0.9359 - val_loss: 2.1139 - val_temperature_loss: 0.0075 - val_temperature_mae: 0.0840 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 28/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - eco2_loss: 0.4592 - eco2_mae: 0.2953 - humidity_loss: 0.3948 - humidity_mae: 0.4602 - loss: 1.1197 - temperature_loss: 0.2068 - temperature_mae: 0.3108 - tvoc_loss: 0.9617 - tvoc_mae: 0.6701 - val_eco2_loss: 0.0048 - val_eco2_mae: 0.0668 - val_humidity_loss: 2.0556 - val_humidity_mae: 0.9371 - val_loss: 2.1189 - val_temperature_loss: 0.0097 - val_temperature_mae: 0.0955 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 29/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - eco2_loss: 0.4574 - eco2_mae: 0.2919 - humidity_loss: 0.3912 - humidity_mae: 0.4582 - loss: 1.1107 - temperature_loss: 0.2024 - temperature_mae: 0.3096 - tvoc_loss: 0.9614 - tvoc_mae: 0.6708 - val_eco2_loss: 0.0040 - val_eco2_mae: 0.0607 - val_humidity_loss: 2.0592 - val_humidity_mae: 0.9385 - val_loss: 2.1248 - val_temperature_loss: 0.0124 - val_temperature_mae: 0.1081 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Epoch 30/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - eco2_loss: 0.4556 - eco2_mae: 0.2884 - humidity_loss: 0.3878 - humidity_mae: 0.4568 - loss: 1.1021 - temperature_loss: 0.1982 - temperature_mae: 0.3079 - tvoc_loss: 0.9610 - tvoc_mae: 0.6715 - val_eco2_loss: 0.0034 - val_eco2_mae: 0.0553 - val_humidity_loss: 2.0623 - val_humidity_mae: 0.9396 - val_loss: 2.1308 - val_temperature_loss: 0.0156 - val_temperature_mae: 0.1219 - val_tvoc_loss: 0.1707 - val_tvoc_mae: 0.4132
# Time to run: 12.5s

# %% [markdown]
# **Evaluate model**

# %%
results = lstm_model.evaluate(test_ds, verbose=0, return_dict=True)

for key, value in results.items():
  print(f"{key}, {value:.4f}\n")
# Out:
# eco2_loss, 0.1564
#
# eco2_mae, 0.3954
#
# humidity_loss, 2.3644
#
# humidity_mae, 1.5350
#
# loss, 5.7853
#
# temperature_loss, 3.2915
#
# temperature_mae, 1.8141
#
# tvoc_loss, 0.1707
#
# tvoc_mae, 0.4132

# %% [markdown]
# # Converting the normalized evaluated units to real units

# %%
# Discussed with ChatGPT how to convert normalized units to real

for key, value in results.items():
    if key.endswith("_mae"):
        var = key.replace("_mae", "")
        mae_real = value * train_std[var]
        print(f"{var}: MAE: {mae_real:.2f} (real units)\n")
# Out:
# eco2: MAE: 24.60 (real units)
#
# humidity: MAE: 5.26 (real units)
#
# temperature: MAE: 0.78 (real units)
#
# tvoc: MAE: 41.31 (real units)

# %% [markdown]
# # Example plot of predictions

# %%
# Define a plot function to show how well it is predicting
# Transformed show_plot method from Laboration 3 in discussion with ChatGPT

def show_plot(history, true_future, model_prediction, title):

    time_steps = range(-len(history), 0)

    plt.figure(figsize=(8,4))
    plt.plot(time_steps, history, '.-', label='History')
    plt.plot(1, true_future, 'rx', markersize=6, label='True Future')
    plt.plot(1, model_prediction, 'go', markersize=6, label='Model Prediction')

    plt.legend()
    plt.title(title)
    plt.ylabel("Normalized value")
    plt.xlabel("Time-Step")
    plt.grid(True)
    plt.show()

# %%
# @title
for x, y in val_ds.take(3):
  predictions = lstm_model.predict(x)
  show_plot(
        x[0, :, 0].numpy(),              # history (time_steps,)
        y["temperature"][0].numpy(),     # true future
        predictions[0][0][0],            # model prediction
        "Temperature"
        )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step

# %%
# @title
for x, y in val_ds.take(3):
  predictions = lstm_model.predict(x)
  show_plot(
        x[0, :, 0].numpy(),              # history (time_steps,)
        y["humidity"][0].numpy(),        # true future
        predictions[0][0][0],            # model prediction
        "humidity"
        )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %%
# @title
for x, y in val_ds.take(3):
  predictions = lstm_model.predict(x)
  show_plot(
        x[0, :, 0].numpy(),              # history (time_steps,)
        y["eco2"][0].numpy(),            # true future
        predictions[0][0][0],            # model prediction
        "eco2"
        )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %%
# @title
for x, y in val_ds.take(3):
  predictions = lstm_model.predict(x)
  show_plot(
        x[0, :, 0].numpy(),              # history (time_steps,)
        y["tvoc"][0].numpy(),            # true future
        predictions[0][0][0],            # model prediction
        "tvoc"
        )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %% [markdown]
# # Plot some unnormalized results

# %%
# Fetch true temperatures

y_true_temp = []

for x, y in test_ds:
  y_true_temp.append(y['temperature'])

y_true_temp = tf.concat(y_true_temp, axis=0).numpy()

# %%
# Perform some predictions

predictions = lstm_model.predict(test_ds)
y_predicted_temp = predictions[0].squeeze() # Predicted temperature output
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step

# %%
# Dynamically written unnorm method
# Returns unnormalized values

def unnorm(y_true, y_pred, attribute):
  y_true_attr = (
      y_true* train_std[attribute]
      + train_mean[attribute]
  )

  y_pred_attr = (
      y_pred * train_std[attribute]
      + train_mean[attribute]
  )
  return y_true_attr, y_pred_attr

# %%
# Call unnorm method with temperature attribute

y_true_temp_unnormalized, y_pred_temp_unnormalized = unnorm(
    y_true_temp,
    y_predicted_temp,
    "temperature"
)

# %%
plt.figure(figsize=(12,6))
plt.plot(y_true_temp_unnormalized, label="True temperature", color="green", alpha=1)
plt.plot(y_pred_temp_unnormalized, label="Predicted temperature", color="red", alpha=1)
plt.ylabel("Temperature (°C)")
plt.xlabel("Time step (1 hour)")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Call unnorm method with eco2 attribute

y_true_temp_unnormalized, y_pred_temp_unnormalized = unnorm(
    y_true_temp,
    y_predicted_temp,
    "eco2"
)

# %%
plt.figure(figsize=(12,6))
plt.plot(y_true_temp_unnormalized, label="True eco2", color="green", alpha=1)
plt.plot(y_pred_temp_unnormalized, label="Predicted eco2", color="red", alpha=1)
plt.ylabel("eco2")
plt.xlabel("Time step (1 hour)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Forecasting several time steps (hours) ahead
# **Reference to all code blocks below: Geron, A. (2019) page 505-511 Hands-on Machine Learning with Scikit-Learn, Keras, and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems. 2nd Edition, O’Reilly Media.**

# %% [markdown]
# **Forecasting several time steps ahead**

# %%
# One step is 1 hour

def recursive_func(model, start_window, steps):
  predictions = []
  window = start_window.numpy().copy()

  for step_ahead in range(steps):
    predictions_output = model.predict(window)
    predictions_output = np.concatenate(predictions_output, axis = 1) # Convert list to array
    predictions.append(predictions_output[0])

    # Push window one timestep ahead
    window = np.concatenate([window[:, 1:, :], predictions_output[:, None, :]], axis=1)

  return np.array(predictions)

# %% [markdown]
# **Perform predictions**

# %%
# Fetch from test dataset
steps=12 # Feel free to alter this variable and rerun from this cell and below to perform predictions from 1-14 steps

for x, y in test_ds.take(1):
  start_window = x[0:1]
  break
predictions = recursive_func(lstm_model, start_window, steps)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %% [markdown]
# **We need to fetch the true future in order to compare our predicted values**

# %%
start_index = split2ix # The beginning of the test data which we already declared in the beginning of the file

true_future = df_1h.iloc[start_index + steps][["temperature", "humidity", "eco2", "tvoc"]].values # Fetch and store true values from where test data starts and 12 hours (steps) ahead

# %%
pred_real = predictions * train_std.values + train_mean.values
last_pred = pred_real[-1]

print(
      steps, "hours ahead:\n"
      "Temperature:", f"{last_pred[0]:.4f}\n",
      "Humidity:", f"{last_pred[1]:.4f}\n",
      "eCO2:", f"{last_pred[2]:.4f}\n",
      "TVOC:", f"{last_pred[3]:.4f}\n"
    )

print(
    "True future values:\n",
    "Temperature:", f"{true_future[0]:.4f}\n",
      "Humidity:", f"{true_future[1]:.4f}\n",
      "eCO2:", f"{true_future[2]:.4f}\n",
      "TVOC:", f"{true_future[3]:.4f}\n"
)
# Out:
# 12 hours ahead:
# Temperature: 20.8180
#  Humidity: 40.4758
#  eCO2: 398.0010
#  TVOC: 41.3076
#
# True future values:
#  Temperature: 20.0000
#  Humidity: 47.7921
#  eCO2: 400.0000
#  TVOC: 0.0000

# %% [markdown]
# # AI-declaration

# %% [markdown]
# **ChatGPT has been used as a discussion partner when exploring and evaluating ideas. Furthermore ChatGPT has been used to give further understanding, for example when I have found myself stuck when transforming code from laborations and/or the book. Especially where code has been designed for univariate outputs and I needed to make them compatible with multivariate outputs/inputs**
